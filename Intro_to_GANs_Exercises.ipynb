# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN](https://github.com/junyanz/CycleGAN)
# * [A whole list](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes fake data to pass to the discriminator. The discriminator also sees real data and predicts if the data it's received is real or fake. The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real data. And the discriminator is trained to figure out which data is real and which is fake. What ends up happening is that the generator learns to make data that is indistiguishable from real data to the discriminator.
#
# ![GAN diagram](assets/gan_diagram.png)
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector the generator uses to contruct it's fake images. As the generator learns through training, it figures out how to map these random vectors to recognizable images that can fool the discriminator.
#
# The output of the discriminator is a sigmoid function, where 0 indicates a fake image and 1 indicates an real image. If you're interested only in generating new images, you can throw out the discriminator after training. Now, let's see how we build this thing in TensorFlow.

# %%
# %matplotlib inline

import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# WARNING:tensorflow:From <ipython-input-3-a37a59f11b0d>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\Rodolfo\Miniconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\Rodolfo\Miniconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\Rodolfo\Miniconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\Rodolfo\Miniconda3\envs\dlnd\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## Model Inputs
#
# First we need to create the inputs for our graph. We need two inputs, one for the discriminator and one for the generator. Here we'll call the discriminator input `inputs_real` and the generator input `inputs_z`. We'll assign them the appropriate sizes for each of the networks.
#
# >**Exercise:** Finish the `model_inputs` function below. Create the placeholders for `inputs_real` and `inputs_z` using the input sizes `real_dim` and `z_dim` respectively.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, shape=(None, real_dim), name='input_real')
    inputs_z = tf.placeholder(tf.float32, shape=(None, z_dim), name='input_z')
    
    return inputs_real, inputs_z

# %% [markdown]
# ## Generator network
#
# ![GAN Network](assets/gan_network.png)
#
# Here we'll build the generator network. To make this network a universal function approximator, we'll need at least one hidden layer. We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# #### Variable Scope
# Here we need to use `tf.variable_scope` for two reasons. Firstly, we're going to make sure all the variable names start with `generator`. Similarly, we'll prepend `discriminator` to the discriminator variables. This will help out later when we're training the separate networks.
#
# We could just use `tf.name_scope` to set the names, but we also want to reuse these networks with different inputs. For the generator, we're going to train it, but also _sample from it_ as we're training and after training. The discriminator will need to share variables between the fake and real input images. So, we can use the `reuse` keyword for `tf.variable_scope` to tell TensorFlow to reuse the variables instead of creating new ones if we build the graph again.
#
# To use `tf.variable_scope`, you use a `with` statement:
# ```python
# with tf.variable_scope('scope_name', reuse=False):
#     # code here
# ```
#
# Here's more from [the TensorFlow documentation](https://www.tensorflow.org/programmers_guide/variable_scope#the_problem) to get another look at using `tf.variable_scope`.
#
# #### Leaky ReLU
# TensorFlow doesn't provide an operation for leaky ReLUs, so we'll need to make one . For this you can just take the outputs from a linear fully connected layer and pass them to `tf.maximum`. Typically, a parameter `alpha` sets the magnitude of the output for negative values. So, the output for negative input (`x`) values is `alpha*x`, and the output for positive `x` is `x`:
# $$
# f(x) = max(\alpha * x, x)
# $$
#
# #### Tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output. This means that we'll have to rescale the MNIST images to be between -1 and 1, instead of 0 and 1.
#
# >**Exercise:** Implement the generator network in the function below. You'll need to return the tanh output. Make sure to wrap your code in a variable scope, with 'generator' as the scope name, and pass the `reuse` keyword argument from the function to `tf.variable_scope`.

# %%
def generator(z, out_dim, n_units=128, reuse=False,  alpha=0.01):
    ''' Build the generator network.
    
        Arguments
        ---------
        z : Input tensor for the generator
        out_dim : Shape of the generator output
        n_units : Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out: 
    '''
    with tf.variable_scope('generator', reuse=reuse): # finish this
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        # Leaky ReLU
        h1 = tf.maximum(alpha*h1, h1)
        
        # Logits and tanh output
        logits = tf.layers.dense(h1, out_dim, activation=None)
        out = tf.tanh(logits)
        
        return out

# %% [markdown]
# ## Discriminator
#
# The discriminator network is almost exactly the same as the generator network, except that we're using a sigmoid output layer.
#
# >**Exercise:** Implement the discriminator network in the function below. Same as above, you'll need to return both the logits and the sigmoid output. Make sure to wrap your code in a variable scope, with 'discriminator' as the scope name, and pass the `reuse` keyword argument from the function arguments to `tf.variable_scope`.

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    ''' Build the discriminator network.
    
        Arguments
        ---------
        x : Input tensor for the discriminator
        n_units: Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out, logits: 
    '''
    with tf.variable_scope('discriminator', reuse=reuse): # finish this
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation= None)
        # Leaky ReLU
        h1 = tf.maximum(h1*alpha, h1)
        
        logits = tf.layers.dense(h1, 1, activation= None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %% [markdown]
# ## Hyperparameters

# %%
# Size of input image to discriminator
input_size = 784 # 28x28 MNIST images flattened
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 128
d_hidden_size = 128
# Leak factor for leaky ReLU
alpha = 0.01
# Label smoothing 
smooth = 0.1

# %% [markdown]
# ## Build network
#
# Now we're building the network from the functions defined above.
#
# First is to get our inputs, `input_real, input_z` from `model_inputs` using the sizes of the input and z.
#
# Then, we'll create the generator, `generator(input_z, input_size)`. This builds the generator with the appropriate input and output sizes.
#
# Then the discriminators. We'll build two of them, one for real data and one for fake data. Since we want the weights to be the same for both real and fake data, we need to reuse the variables. For the fake data, we're getting it from the generator as `g_model`. So the real data discriminator is `discriminator(input_real)` while the fake discriminator is `discriminator(g_model, reuse=True)`.
#
# >**Exercise:** Build the network from the functions you defined earlier.

# %%
tf.reset_default_graph()
# Create our input placeholders
input_real, input_z = model_inputs(input_size, z_size)

# Generator network here
g_model = generator(input_z, input_size, n_units=128, reuse=False,  alpha=0.01)
# g_model is the generator output

# Discriminator network here
d_model_real, d_logits_real = discriminator(input_real)
d_model_fake, d_logits_fake = discriminator(g_model, reuse = True)

# %% [markdown]
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses, which is a little tricky. For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_loss_real + d_loss_fake`. The losses will be sigmoid cross-entropies, which we can get with `tf.nn.sigmoid_cross_entropy_with_logits`. We'll also wrap that in `tf.reduce_mean` to get the mean for all the images in the batch. So the losses will look something like
#
# ```python
# tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))
# ```
#
# For the real image logits, we'll use `d_logits_real` which we got from the discriminator in the cell above. For the labels, we want them to be all ones, since these are all real images. To help the discriminator generalize better, the labels are reduced a bit from 1.0 to 0.9, for example,  using the parameter `smooth`. This is known as label smoothing, typically used with classifiers to improve performance. In TensorFlow, it looks something like `labels = tf.ones_like(tensor) * (1 - smooth)`
#
# The discriminator loss for the fake data is similar. The logits are `d_logits_fake`, which we got from passing the generator output to the discriminator. These fake logits are used with labels of all zeros. Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# Finally, the generator losses are using `d_logits_fake`, the fake image logits. But, now the labels are all ones. The generator is trying to fool the discriminator, so it wants to discriminator to output ones for fake images.
#
# >**Exercise:** Calculate the losses for the discriminator and the generator. There are two discriminator losses, one for real images and one for fake images. For the real image loss, use the real logits and (smoothed) labels of ones. For the fake image loss, use the fake logits with labels of all zeros. The total discriminator loss is the sum of those two losses. Finally, the generator loss again uses the fake logits from the discriminator, but this time the labels are all ones because the generator wants to fool the discriminator.

# %%
# Calculate losses
d_labels_real = tf.ones_like(d_logits_real) * (1 - smooth)
d_labels_fake = tf.zeros_like(d_logits_real)

d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=d_labels_real))
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=d_labels_fake))

d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_logits_fake)))

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So we need to get the variables for each part and build optimizers for the two parts. To get all the trainable variables, we use `tf.trainable_variables()`. This creates a list of all the variables we've defined in our graph.
#
# For the generator optimizer, we only want to generator variables. Our past selves were nice and used a variable scope to start all of our generator variable names with `generator`. So, we just need to iterate through the list from `tf.trainable_variables()` and keep variables that start with `generator`. Each variable object has an attribute `name` which holds the name of the variable as a string (`var.name == 'weights_0'` for instance).
#
# We can do something similar with the discriminator. All the variables in the discriminator start with `discriminator`.
#
# Then, in the optimizer we pass the variable lists to the `var_list` keyword argument of the `minimize` method. This tells the optimizer to only update the listed variables. Something like `tf.train.AdamOptimizer().minimize(loss, var_list=var_list)` will only train the variables in `var_list`.
#
# >**Exercise: ** Below, implement the optimizers for the generator and discriminator. First you'll need to get a list of trainable variables, then split that list into two lists, one for the generator variables and another for the discriminator variables. Finally, using `AdamOptimizer`, create an optimizer for each network that update the network variables separately.

# %%
# Optimizers
learning_rate = 0.002

# Get the trainable_variables, split into G and D parts
t_vars = tf.trainable_variables()
g_vars = [i for i in t_vars if i.name.startswith('generator')]
d_vars = [j for j in t_vars if j.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer().minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer().minimize(g_loss, var_list=g_vars)

# %% [markdown]
# ## Training

# %%
batch_size = 100
epochs = 300
samples = []
losses = []
saver = tf.train.Saver(var_list = g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/300... Discriminator Loss: 0.3535... Generator Loss: 3.9731
# Epoch 2/300... Discriminator Loss: 0.3626... Generator Loss: 3.9869
# Epoch 3/300... Discriminator Loss: 0.4176... Generator Loss: 3.1985
# Epoch 4/300... Discriminator Loss: 0.8017... Generator Loss: 2.1525
# Epoch 5/300... Discriminator Loss: 1.4199... Generator Loss: 2.4220
# Epoch 6/300... Discriminator Loss: 0.6582... Generator Loss: 3.7847
# Epoch 7/300... Discriminator Loss: 0.5453... Generator Loss: 3.5724
# Epoch 8/300... Discriminator Loss: 0.7810... Generator Loss: 2.5842
# Epoch 9/300... Discriminator Loss: 1.0581... Generator Loss: 1.7412
# Epoch 10/300... Discriminator Loss: 1.3501... Generator Loss: 2.3317
# Epoch 11/300... Discriminator Loss: 0.9966... Generator Loss: 3.6969
# Epoch 12/300... Discriminator Loss: 1.1176... Generator Loss: 2.8202
# Epoch 13/300... Discriminator Loss: 1.0935... Generator Loss: 1.7538
# Epoch 14/300... Discriminator Loss: 1.3561... Generator Loss: 1.6680
# Epoch 15/300... Discriminator Loss: 0.7380... Generator Loss: 2.3913
# Epoch 16/300... Discriminator Loss: 1.0751... Generator Loss: 2.0214
# Epoch 17/300... Discriminator Loss: 1.4421... Generator Loss: 1.2483
# Epoch 18/300... Discriminator Loss: 0.9276... Generator Loss: 2.7367
# Epoch 19/300... Discriminator Loss: 1.6575... Generator Loss: 1.7749
# Epoch 20/300... Discriminator Loss: 1.1183... Generator Loss: 1.4491
# Epoch 21/300... Discriminator Loss: 1.2316... Generator Loss: 1.6722
# Epoch 22/300... Discriminator Loss: 1.0611... Generator Loss: 2.2211
# Epoch 23/300... Discriminator Loss: 1.2653... Generator Loss: 1.1423
# Epoch 24/300... Discriminator Loss: 1.6395... Generator Loss: 1.5411
# Epoch 25/300... Discriminator Loss: 1.1095... Generator Loss: 2.0122
# Epoch 26/300... Discriminator Loss: 0.7031... Generator Loss: 2.5495
# Epoch 27/300... Discriminator Loss: 1.1242... Generator Loss: 1.8104
# Epoch 28/300... Discriminator Loss: 1.2416... Generator Loss: 1.6648
# Epoch 29/300... Discriminator Loss: 1.2658... Generator Loss: 1.3702
# Epoch 30/300... Discriminator Loss: 1.4739... Generator Loss: 1.2778
# Epoch 31/300... Discriminator Loss: 0.9836... Generator Loss: 1.8110
# Epoch 32/300... Discriminator Loss: 1.2070... Generator Loss: 1.5615
# Epoch 33/300... Discriminator Loss: 1.4488... Generator Loss: 1.5574
# Epoch 34/300... Discriminator Loss: 1.1097... Generator Loss: 1.4666
# Epoch 35/300... Discriminator Loss: 1.1075... Generator Loss: 1.8010
# Epoch 36/300... Discriminator Loss: 1.0154... Generator Loss: 1.8791
# Epoch 37/300... Discriminator Loss: 1.0123... Generator Loss: 1.7811
# Epoch 38/300... Discriminator Loss: 1.1254... Generator Loss: 1.2395
# Epoch 39/300... Discriminator Loss: 1.3278... Generator Loss: 1.5192
# Epoch 40/300... Discriminator Loss: 1.0542... Generator Loss: 1.9448
# Epoch 41/300... Discriminator Loss: 0.7642... Generator Loss: 2.4788
# Epoch 42/300... Discriminator Loss: 1.3417... Generator Loss: 1.0646
# Epoch 43/300... Discriminator Loss: 1.0883... Generator Loss: 1.6741
# Epoch 44/300... Discriminator Loss: 1.0979... Generator Loss: 1.6196
# Epoch 45/300... Discriminator Loss: 0.9169... Generator Loss: 2.2387
# Epoch 46/300... Discriminator Loss: 1.1419... Generator Loss: 1.4975
# Epoch 47/300... Discriminator Loss: 0.9544... Generator Loss: 1.5671
# Epoch 48/300... Discriminator Loss: 0.9489... Generator Loss: 1.9418
# Epoch 49/300... Discriminator Loss: 0.9798... Generator Loss: 1.5087
# Epoch 50/300... Discriminator Loss: 0.9319... Generator Loss: 2.2521
# Epoch 51/300... Discriminator Loss: 0.9916... Generator Loss: 1.6394
# Epoch 52/300... Discriminator Loss: 0.9472... Generator Loss: 1.6929
# Epoch 53/300... Discriminator Loss: 0.8626... Generator Loss: 2.0385
# Epoch 54/300... Discriminator Loss: 0.8230... Generator Loss: 2.1176
# Epoch 55/300... Discriminator Loss: 0.8429... Generator Loss: 1.6940
# Epoch 56/300... Discriminator Loss: 1.1088... Generator Loss: 1.5376
# Epoch 57/300... Discriminator Loss: 1.0050... Generator Loss: 1.9356
# Epoch 58/300... Discriminator Loss: 0.8391... Generator Loss: 2.1117
# Epoch 59/300... Discriminator Loss: 1.1413... Generator Loss: 1.7888
# Epoch 60/300... Discriminator Loss: 1.1970... Generator Loss: 1.5109
# Epoch 61/300... Discriminator Loss: 1.0044... Generator Loss: 1.6388
# Epoch 62/300... Discriminator Loss: 0.8693... Generator Loss: 2.0464
# Epoch 63/300... Discriminator Loss: 1.0532... Generator Loss: 1.7952
# Epoch 64/300... Discriminator Loss: 1.1284... Generator Loss: 1.3412
# Epoch 65/300... Discriminator Loss: 1.1033... Generator Loss: 1.5748
# Epoch 66/300... Discriminator Loss: 1.1371... Generator Loss: 1.5814
# Epoch 67/300... Discriminator Loss: 1.0901... Generator Loss: 1.8117
# Epoch 68/300... Discriminator Loss: 0.8433... Generator Loss: 2.3295
# Epoch 69/300... Discriminator Loss: 0.7866... Generator Loss: 2.2344
# Epoch 70/300... Discriminator Loss: 0.7281... Generator Loss: 2.1892
# Epoch 71/300... Discriminator Loss: 0.9036... Generator Loss: 1.6709
# Epoch 72/300... Discriminator Loss: 0.9333... Generator Loss: 2.1921
# Epoch 73/300... Discriminator Loss: 0.8396... Generator Loss: 2.1604
# Epoch 74/300... Discriminator Loss: 1.0701... Generator Loss: 1.5575
# Epoch 75/300... Discriminator Loss: 0.8323... Generator Loss: 1.9624
# Epoch 76/300... Discriminator Loss: 1.0737... Generator Loss: 1.7292
# Epoch 77/300... Discriminator Loss: 0.9104... Generator Loss: 1.8735
# Epoch 78/300... Discriminator Loss: 0.8025... Generator Loss: 2.3826
# Epoch 79/300... Discriminator Loss: 0.9538... Generator Loss: 1.7275
# Epoch 80/300... Discriminator Loss: 0.9710... Generator Loss: 2.1529
# Epoch 81/300... Discriminator Loss: 1.2341... Generator Loss: 1.4165
# Epoch 82/300... Discriminator Loss: 0.9790... Generator Loss: 1.8065
# Epoch 83/300... Discriminator Loss: 1.2870... Generator Loss: 1.2602
# Epoch 84/300... Discriminator Loss: 1.1238... Generator Loss: 1.6836
# Epoch 85/300... Discriminator Loss: 0.8978... Generator Loss: 1.9958
# Epoch 86/300... Discriminator Loss: 0.8949... Generator Loss: 1.8418
# Epoch 87/300... Discriminator Loss: 0.9339... Generator Loss: 1.6631
# Epoch 88/300... Discriminator Loss: 1.1707... Generator Loss: 1.4792
# Epoch 89/300... Discriminator Loss: 1.0649... Generator Loss: 1.5342
# Epoch 90/300... Discriminator Loss: 0.9975... Generator Loss: 1.8530
# Epoch 91/300... Discriminator Loss: 1.2779... Generator Loss: 1.4184
# Epoch 92/300... Discriminator Loss: 1.0650... Generator Loss: 1.4007
# Epoch 93/300... Discriminator Loss: 1.0076... Generator Loss: 1.9587
# Epoch 94/300... Discriminator Loss: 1.1804... Generator Loss: 1.8012
# Epoch 95/300... Discriminator Loss: 1.1810... Generator Loss: 1.5517
# Epoch 96/300... Discriminator Loss: 1.0853... Generator Loss: 1.7724
# Epoch 97/300... Discriminator Loss: 1.0548... Generator Loss: 1.5527
# Epoch 98/300... Discriminator Loss: 1.0997... Generator Loss: 1.6477
# Epoch 99/300... Discriminator Loss: 1.0535... Generator Loss: 1.7224
# Epoch 100/300... Discriminator Loss: 1.0923... Generator Loss: 1.5156
# Epoch 101/300... Discriminator Loss: 1.0516... Generator Loss: 1.6076
# Epoch 102/300... Discriminator Loss: 1.0051... Generator Loss: 1.7808
# Epoch 103/300... Discriminator Loss: 0.9458... Generator Loss: 1.8023
# Epoch 104/300... Discriminator Loss: 1.1826... Generator Loss: 1.5132
# Epoch 105/300... Discriminator Loss: 0.9455... Generator Loss: 2.0594
# Epoch 106/300... Discriminator Loss: 1.2128... Generator Loss: 1.6942
# Epoch 107/300... Discriminator Loss: 1.1380... Generator Loss: 1.7985
# Epoch 108/300... Discriminator Loss: 1.0587... Generator Loss: 1.6501
# Epoch 109/300... Discriminator Loss: 0.9567... Generator Loss: 1.8908
# Epoch 110/300... Discriminator Loss: 1.0899... Generator Loss: 1.6882
# Epoch 111/300... Discriminator Loss: 1.1417... Generator Loss: 1.5213
# Epoch 112/300... Discriminator Loss: 1.2245... Generator Loss: 1.5107
# Epoch 113/300... Discriminator Loss: 1.1943... Generator Loss: 1.6517
# Epoch 114/300... Discriminator Loss: 1.0489... Generator Loss: 1.5766
# Epoch 115/300... Discriminator Loss: 1.1813... Generator Loss: 1.6222
# Epoch 116/300... Discriminator Loss: 1.0467... Generator Loss: 1.8003
# Epoch 117/300... Discriminator Loss: 1.2059... Generator Loss: 1.0636
# Epoch 118/300... Discriminator Loss: 1.1364... Generator Loss: 1.6735
# Epoch 119/300... Discriminator Loss: 1.1267... Generator Loss: 1.5313
# Epoch 120/300... Discriminator Loss: 0.9944... Generator Loss: 1.6346
# Epoch 121/300... Discriminator Loss: 1.1170... Generator Loss: 1.3359
# Epoch 122/300... Discriminator Loss: 0.9452... Generator Loss: 1.5122
# Epoch 123/300... Discriminator Loss: 1.0476... Generator Loss: 1.5344
# Epoch 124/300... Discriminator Loss: 0.9439... Generator Loss: 1.8278
# Epoch 125/300... Discriminator Loss: 1.0043... Generator Loss: 1.7101
# Epoch 126/300... Discriminator Loss: 1.0473... Generator Loss: 1.5716
# Epoch 127/300... Discriminator Loss: 1.2454... Generator Loss: 1.0416
# Epoch 128/300... Discriminator Loss: 1.0588... Generator Loss: 1.8265
# Epoch 129/300... Discriminator Loss: 1.3024... Generator Loss: 1.7164
# Epoch 130/300... Discriminator Loss: 1.2389... Generator Loss: 1.4062
# Epoch 131/300... Discriminator Loss: 0.9762... Generator Loss: 1.4675
# Epoch 132/300... Discriminator Loss: 0.9904... Generator Loss: 1.5849
# Epoch 133/300... Discriminator Loss: 1.1503... Generator Loss: 1.2323
# Epoch 134/300... Discriminator Loss: 0.9840... Generator Loss: 1.6770
# Epoch 135/300... Discriminator Loss: 0.9644... Generator Loss: 1.9814
# Epoch 136/300... Discriminator Loss: 1.2238... Generator Loss: 1.3972
# Epoch 137/300... Discriminator Loss: 1.1039... Generator Loss: 1.4373
# Epoch 138/300... Discriminator Loss: 1.0434... Generator Loss: 1.6821
# Epoch 139/300... Discriminator Loss: 1.1464... Generator Loss: 1.3539
# Epoch 140/300... Discriminator Loss: 1.2457... Generator Loss: 1.1279
# Epoch 141/300... Discriminator Loss: 1.0652... Generator Loss: 1.4698
# Epoch 142/300... Discriminator Loss: 1.1242... Generator Loss: 1.6134
# Epoch 143/300... Discriminator Loss: 0.9731... Generator Loss: 1.7974
# Epoch 144/300... Discriminator Loss: 1.0763... Generator Loss: 1.6760
# Epoch 145/300... Discriminator Loss: 1.0279... Generator Loss: 1.5499
# Epoch 146/300... Discriminator Loss: 1.2035... Generator Loss: 1.3060
# Epoch 147/300... Discriminator Loss: 1.2200... Generator Loss: 1.1727
# Epoch 148/300... Discriminator Loss: 1.1904... Generator Loss: 1.6247
# Epoch 149/300... Discriminator Loss: 1.1260... Generator Loss: 1.7395
# Epoch 150/300... Discriminator Loss: 1.0915... Generator Loss: 1.3097
# Epoch 151/300... Discriminator Loss: 0.9930... Generator Loss: 1.7247
# Epoch 152/300... Discriminator Loss: 1.2606... Generator Loss: 1.4892
# Epoch 153/300... Discriminator Loss: 1.0280... Generator Loss: 1.4845
# Epoch 154/300... Discriminator Loss: 1.0628... Generator Loss: 1.7866
# Epoch 155/300... Discriminator Loss: 1.0125... Generator Loss: 1.6605
# Epoch 156/300... Discriminator Loss: 1.0000... Generator Loss: 1.6571
# Epoch 157/300... Discriminator Loss: 0.9276... Generator Loss: 1.7408
# Epoch 158/300... Discriminator Loss: 1.1170... Generator Loss: 1.4789
# Epoch 159/300... Discriminator Loss: 1.1140... Generator Loss: 1.5164
# Epoch 160/300... Discriminator Loss: 1.3642... Generator Loss: 1.3846
# Epoch 161/300... Discriminator Loss: 1.0407... Generator Loss: 1.5175
# Epoch 162/300... Discriminator Loss: 0.9711... Generator Loss: 1.7800
# Epoch 163/300... Discriminator Loss: 1.0398... Generator Loss: 1.7523
# Epoch 164/300... Discriminator Loss: 0.9810... Generator Loss: 1.6925
# Epoch 165/300... Discriminator Loss: 1.0469... Generator Loss: 1.5194
# Epoch 166/300... Discriminator Loss: 1.0220... Generator Loss: 1.3804
# Epoch 167/300... Discriminator Loss: 1.2120... Generator Loss: 1.2782
# Epoch 168/300... Discriminator Loss: 1.0729... Generator Loss: 1.5222
# Epoch 169/300... Discriminator Loss: 1.1737... Generator Loss: 1.5601
# Epoch 170/300... Discriminator Loss: 1.1042... Generator Loss: 1.4570
# Epoch 171/300... Discriminator Loss: 0.9702... Generator Loss: 1.9377
# Epoch 172/300... Discriminator Loss: 1.2035... Generator Loss: 1.2919
# Epoch 173/300... Discriminator Loss: 0.9644... Generator Loss: 1.8148
# Epoch 174/300... Discriminator Loss: 0.9726... Generator Loss: 1.6011
# Epoch 175/300... Discriminator Loss: 1.0901... Generator Loss: 1.5676
# Epoch 176/300... Discriminator Loss: 1.1703... Generator Loss: 1.7024
# Epoch 177/300... Discriminator Loss: 0.9550... Generator Loss: 1.5676
# Epoch 178/300... Discriminator Loss: 1.0633... Generator Loss: 1.5177
# Epoch 179/300... Discriminator Loss: 1.0244... Generator Loss: 1.4650
# Epoch 180/300... Discriminator Loss: 1.1862... Generator Loss: 1.3734
# Epoch 181/300... Discriminator Loss: 0.9534... Generator Loss: 1.7492
# Epoch 182/300... Discriminator Loss: 1.1472... Generator Loss: 1.4097
# Epoch 183/300... Discriminator Loss: 1.1210... Generator Loss: 1.5432
# Epoch 184/300... Discriminator Loss: 1.1547... Generator Loss: 1.6057
# Epoch 185/300... Discriminator Loss: 1.0198... Generator Loss: 1.5091
# Epoch 186/300... Discriminator Loss: 1.1241... Generator Loss: 1.4334
# Epoch 187/300... Discriminator Loss: 1.1202... Generator Loss: 1.4457
# Epoch 188/300... Discriminator Loss: 1.1957... Generator Loss: 1.4395
# Epoch 189/300... Discriminator Loss: 0.9628... Generator Loss: 1.5228
# Epoch 190/300... Discriminator Loss: 1.1067... Generator Loss: 1.4561
# Epoch 191/300... Discriminator Loss: 0.9873... Generator Loss: 1.6787
# Epoch 192/300... Discriminator Loss: 1.1115... Generator Loss: 1.5645
# Epoch 193/300... Discriminator Loss: 1.0623... Generator Loss: 1.3708
# Epoch 194/300... Discriminator Loss: 1.0779... Generator Loss: 1.4515
# Epoch 195/300... Discriminator Loss: 1.0266... Generator Loss: 1.6033
# Epoch 196/300... Discriminator Loss: 1.1322... Generator Loss: 1.7581
# Epoch 197/300... Discriminator Loss: 1.0878... Generator Loss: 1.5873
# Epoch 198/300... Discriminator Loss: 1.0210... Generator Loss: 1.7073
# Epoch 199/300... Discriminator Loss: 1.1037... Generator Loss: 1.3233
# Epoch 200/300... Discriminator Loss: 1.0799... Generator Loss: 1.2502
# Epoch 201/300... Discriminator Loss: 1.0625... Generator Loss: 1.5235
# Epoch 202/300... Discriminator Loss: 1.0252... Generator Loss: 1.5914
# Epoch 203/300... Discriminator Loss: 1.1217... Generator Loss: 1.5444
# Epoch 204/300... Discriminator Loss: 1.0881... Generator Loss: 1.6359
# Epoch 205/300... Discriminator Loss: 1.1476... Generator Loss: 1.4892
# Epoch 206/300... Discriminator Loss: 1.0812... Generator Loss: 1.5531
# Epoch 207/300... Discriminator Loss: 1.1137... Generator Loss: 1.4286
# Epoch 208/300... Discriminator Loss: 1.0980... Generator Loss: 1.4222
# Epoch 209/300... Discriminator Loss: 1.1270... Generator Loss: 1.5163
# Epoch 210/300... Discriminator Loss: 1.0590... Generator Loss: 1.5701
# Epoch 211/300... Discriminator Loss: 1.0710... Generator Loss: 1.4822
# Epoch 212/300... Discriminator Loss: 1.0492... Generator Loss: 1.2230
# Epoch 213/300... Discriminator Loss: 1.0586... Generator Loss: 1.4919
# Epoch 214/300... Discriminator Loss: 1.0825... Generator Loss: 1.6065
# Epoch 215/300... Discriminator Loss: 1.1579... Generator Loss: 1.4361
# Epoch 216/300... Discriminator Loss: 1.0396... Generator Loss: 1.5329
# Epoch 217/300... Discriminator Loss: 1.0751... Generator Loss: 1.4249
# Epoch 218/300... Discriminator Loss: 0.9414... Generator Loss: 1.8633
# Epoch 219/300... Discriminator Loss: 0.9977... Generator Loss: 1.3332
# Epoch 220/300... Discriminator Loss: 1.1393... Generator Loss: 1.7389
# Epoch 221/300... Discriminator Loss: 1.0283... Generator Loss: 1.7546
# Epoch 222/300... Discriminator Loss: 1.0531... Generator Loss: 1.5135
# Epoch 223/300... Discriminator Loss: 1.1117... Generator Loss: 1.4305
# Epoch 224/300... Discriminator Loss: 0.9823... Generator Loss: 1.8770
# Epoch 225/300... Discriminator Loss: 1.0572... Generator Loss: 1.6543
# Epoch 226/300... Discriminator Loss: 1.1646... Generator Loss: 1.3274
# Epoch 227/300... Discriminator Loss: 0.8848... Generator Loss: 1.5844
# Epoch 228/300... Discriminator Loss: 1.1311... Generator Loss: 1.2617
# Epoch 229/300... Discriminator Loss: 1.1717... Generator Loss: 1.4377
# Epoch 230/300... Discriminator Loss: 1.1466... Generator Loss: 1.3884
# Epoch 231/300... Discriminator Loss: 1.1329... Generator Loss: 1.4582
# Epoch 232/300... Discriminator Loss: 1.0924... Generator Loss: 1.6023
# Epoch 233/300... Discriminator Loss: 1.1656... Generator Loss: 1.3778
# Epoch 234/300... Discriminator Loss: 1.1569... Generator Loss: 1.3003
# Epoch 235/300... Discriminator Loss: 1.0424... Generator Loss: 1.6777
# Epoch 236/300... Discriminator Loss: 1.0919... Generator Loss: 1.4719
# Epoch 237/300... Discriminator Loss: 1.1380... Generator Loss: 1.2914
# Epoch 238/300... Discriminator Loss: 0.9926... Generator Loss: 1.5668
# Epoch 239/300... Discriminator Loss: 1.1733... Generator Loss: 1.4163
# Epoch 240/300... Discriminator Loss: 1.1539... Generator Loss: 1.4761
# Epoch 241/300... Discriminator Loss: 1.1093... Generator Loss: 1.8002
# Epoch 242/300... Discriminator Loss: 1.1232... Generator Loss: 1.3931
# Epoch 243/300... Discriminator Loss: 1.0766... Generator Loss: 1.3313
# Epoch 244/300... Discriminator Loss: 1.0182... Generator Loss: 1.8462
# Epoch 245/300... Discriminator Loss: 0.9610... Generator Loss: 1.6401
# Epoch 246/300... Discriminator Loss: 1.0717... Generator Loss: 1.3727
# Epoch 247/300... Discriminator Loss: 1.0725... Generator Loss: 1.5295
# Epoch 248/300... Discriminator Loss: 1.0437... Generator Loss: 1.6256
# Epoch 249/300... Discriminator Loss: 1.0379... Generator Loss: 1.8125
# Epoch 250/300... Discriminator Loss: 1.0670... Generator Loss: 1.6955
# Epoch 251/300... Discriminator Loss: 1.0362... Generator Loss: 1.5295
# Epoch 252/300... Discriminator Loss: 0.9607... Generator Loss: 1.7084
# Epoch 253/300... Discriminator Loss: 1.1429... Generator Loss: 1.4206
# Epoch 254/300... Discriminator Loss: 1.1402... Generator Loss: 1.7010
# Epoch 255/300... Discriminator Loss: 0.9426... Generator Loss: 1.5615
# Epoch 256/300... Discriminator Loss: 1.1096... Generator Loss: 1.5334
# Epoch 257/300... Discriminator Loss: 1.0999... Generator Loss: 1.2590
# Epoch 258/300... Discriminator Loss: 1.0424... Generator Loss: 1.6546
# Epoch 259/300... Discriminator Loss: 1.0746... Generator Loss: 1.7042
# Epoch 260/300... Discriminator Loss: 1.0507... Generator Loss: 1.4916
# Epoch 261/300... Discriminator Loss: 0.9978... Generator Loss: 1.5249
# Epoch 262/300... Discriminator Loss: 1.0295... Generator Loss: 1.6150
# Epoch 263/300... Discriminator Loss: 1.0743... Generator Loss: 1.6685
# Epoch 264/300... Discriminator Loss: 1.1017... Generator Loss: 1.2514
# Epoch 265/300... Discriminator Loss: 1.0789... Generator Loss: 1.6645
# Epoch 266/300... Discriminator Loss: 1.1179... Generator Loss: 1.3237
# Epoch 267/300... Discriminator Loss: 1.0117... Generator Loss: 1.4958
# Epoch 268/300... Discriminator Loss: 1.1696... Generator Loss: 1.5489
# Epoch 269/300... Discriminator Loss: 1.1310... Generator Loss: 1.1776
# Epoch 270/300... Discriminator Loss: 1.2212... Generator Loss: 1.3803
# Epoch 271/300... Discriminator Loss: 1.0973... Generator Loss: 1.5134
# Epoch 272/300... Discriminator Loss: 1.0280... Generator Loss: 1.7957
# Epoch 273/300... Discriminator Loss: 1.0067... Generator Loss: 1.3954
# Epoch 274/300... Discriminator Loss: 1.0573... Generator Loss: 1.5701
# Epoch 275/300... Discriminator Loss: 1.0538... Generator Loss: 1.3979
# Epoch 276/300... Discriminator Loss: 1.0309... Generator Loss: 1.4874
# Epoch 277/300... Discriminator Loss: 0.9881... Generator Loss: 1.3494
# Epoch 278/300... Discriminator Loss: 1.1167... Generator Loss: 1.4820
# Epoch 279/300... Discriminator Loss: 1.0208... Generator Loss: 1.6809
# Epoch 280/300... Discriminator Loss: 1.0882... Generator Loss: 1.4891
# Epoch 281/300... Discriminator Loss: 1.1610... Generator Loss: 1.2670
# Epoch 282/300... Discriminator Loss: 1.0337... Generator Loss: 1.6396
# Epoch 283/300... Discriminator Loss: 1.0056... Generator Loss: 1.6342
# Epoch 284/300... Discriminator Loss: 1.1275... Generator Loss: 1.3364
# Epoch 285/300... Discriminator Loss: 1.1415... Generator Loss: 1.4271
# Epoch 286/300... Discriminator Loss: 1.1249... Generator Loss: 1.5817
# Epoch 287/300... Discriminator Loss: 1.0402... Generator Loss: 1.4762
# Epoch 288/300... Discriminator Loss: 0.9721... Generator Loss: 1.5809
# Epoch 289/300... Discriminator Loss: 1.0908... Generator Loss: 1.5296
# Epoch 290/300... Discriminator Loss: 0.9240... Generator Loss: 1.6665
# Epoch 291/300... Discriminator Loss: 1.0242... Generator Loss: 1.5640
# Epoch 292/300... Discriminator Loss: 1.0081... Generator Loss: 1.5463
# Epoch 293/300... Discriminator Loss: 1.1575... Generator Loss: 1.4407
# Epoch 294/300... Discriminator Loss: 1.1248... Generator Loss: 1.6206
# Epoch 295/300... Discriminator Loss: 1.0806... Generator Loss: 1.3744
# Epoch 296/300... Discriminator Loss: 1.2470... Generator Loss: 1.5040
# Epoch 297/300... Discriminator Loss: 1.1599... Generator Loss: 1.4812
# Epoch 298/300... Discriminator Loss: 0.9114... Generator Loss: 1.5556
# Epoch 299/300... Discriminator Loss: 1.0530... Generator Loss: 1.6161
# Epoch 300/300... Discriminator Loss: 1.1201... Generator Loss: 1.3767

# %% [markdown]
# ## Training loss
#
# Here we'll check out the training losses for the generator and discriminator.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at images taken while training.

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 5, 7, 3, 0, 9. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs. With bonus optical illusion!

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise. Looks like 1, 9, and 8 show up first. Then, it learns 5 and 3.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. We just need to pass in a new latent vector $z$ and we'll get new samples!

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                   feed_dict={input_z: sample_z})
view_samples(0, [gen_samples])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt
# (<Figure size 504x504 with 16 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002830B28D978>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B26E438>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B08BB70>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B0ABBA8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002830B0CFD68>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B0FF160>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B126550>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B151940>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002830B178D30>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B1AA160>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B1D3550>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B1FC940>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000002830B224D30>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B438160>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B45F550>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000002830B488940>]],
#        dtype=object))
